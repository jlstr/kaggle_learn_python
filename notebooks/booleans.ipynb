# %%
x = True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %%
def can_run_for_president(age):
  """Can someone of the given age run for president in the US?"""
  # The US Constitution says you must be at least 35 years old
  return age >= 35

bitch_age = 24

print(f"Can a bitch that's {bitch_age} run for president? Answer: {can_run_for_president(bitch_age)}")
# Out:
# Can a bitch that's 24 run for president? Answer: False

# %%
3.0 == 3
# Out:
# True

# %%
"3" == 3.0
# Out:
# False

# %%
def is_odd(n):
  return (n % 2) == 1

num = 100

print(f"is {num} odd? - Answer: {is_odd(num)}")
# Out:
# is 100 odd? - Answer: False

# %%
def can_run_for_president(age, is_natural_born_citizen):
  """Can someone of the given age and citizenship status run for president in the US?"""
  # The US Constitution says you must be a natural born citizen *and* at least 35 years old
  return is_natural_born_citizen and (age >= 35)

help(can_run_for_president)

print(can_run_for_president(19, True))
# Out:
# Help on function can_run_for_president in module __main__:
#
# can_run_for_president(age, is_natural_born_citizen)
#     Can someone of the given age and citizenship status run for president in the US?
#
# False

# %%
True or True and False
# Out:
# True

# %%
def inspect(x):
  if x == 0:
    print(x, "is zero")
  elif x > 0:
    print(x, "is positive")
  elif x < 0:
    print(x, "is negative")
  else:
    print(x, "is unlike anything I've ever seen...")

inspect(0)
inspect(-666)
# Out:
# 0 is zero
# -666 is negative

# %%
def f(x):
  if x > 0:
    print("Only printed when x is positive; x =", x)
    print("Also only printed when x is positive; x =", x)
    if x == 666:
      print("El numero de la Bestia")
  print("Always printed, regardless of x's value; x =", x)

f(666)
f(777)
# Out:
# Only printed when x is positive; x = 666
# Also only printed when x is positive; x = 666
# El numero de la Bestia
# Always printed, regardless of x's value; x = 666
# Only printed when x is positive; x = 777
# Also only printed when x is positive; x = 777
# Always printed, regardless of x's value; x = 777

# %%
print(bool(1)) # all numbers are treated as true, except 0
print(bool(0))
print(bool("asf")) # all strings are treated as true, except the empty string ""
print(bool(""))
# Generally empty sequences (strings, lists, and other types we've yet to see like lists and tuples)
# are "falsey" and the rest are "truthy"
# Out:
# True
# False
# True
# False

# %%
if 0:
  print(0)
elif "spam":
  print("spam")
# Out:
# spam
